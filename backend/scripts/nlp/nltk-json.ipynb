# %%
# !pip install textblob
# !pip install -U pip setuptools wheel
# !pip install -U spacy
# !python -m spacy download en_core_web_sm

# %%
import sys
from os import path
from os.path import exists
import string
from collections import Counter
from tokenize import maybe
import nltk
import matplotlib.pyplot as plt
from textblob import TextBlob
from pathlib import Path
from textblob.sentiments import NaiveBayesAnalyzer
import nltk.corpus
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
from nltk.corpus import stopwords
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import nltk.corpus
from nltk.tokenize import RegexpTokenizer
from nltk.tokenize import word_tokenize
from nltk.data import load
fdist = FreqDist()

# downloading required packages
nltk.download('nps_chat')
nltk.download('punkt')
nltk.download('brown')
nltk.download('movie_reviews')
nltk.download('stopwords')
nltk.download('vader_lexicon')
nltk.download('tagsets')
nltk.download('averaged_perceptron_tagger')
# nltk.help.upenn_tagset('MD')

print('\n'+'******************************************************************')
print('This application is about Natural Language Processing (NLP).')
print('The user enters sentence(s) add using NLP and other algorithm the application')
print('will analyze that entry and gives some feesback.')
print('\n'+'*****   THIS APPLICATION DOES NOT SUPPORT CONTRACTED FORM    *****'+'\n')
print('******************************************************************')


def main():

    #     myPath = input('\n'+'Enter the path for the file:')

    # Entry validation for path

    # while path.exists(str(myPath)) != True:
    #     print('\n'+'\n'+' *** This path does not exist, please try again! ***')
    #     myPath = input('\n'+ 'Enter the path:')
    # myFile= input('Enter the text file name:')

    # Entry validation for the text file to be exist

    # while exists(myFile)!= True:
    #     print('\n'+'\n'+' *** This file does not exist, please try again! ***')
    #     myFile= input('Enter the text file name:')
    # while '.txt' not in myFile and '.text' not in myFile:
    #     print('\n'+'You did not provide a valid text file; *** A valid text file has .txt or .text at the end ***')
    #     answer = input('Do you want to try again? (y/n)')
    #     if answer.upper() == 'N':
    #         sys.exit('Thank you! You successfully stopped the program')
    #     else:
    #         myFile = input('\n'+ 'Enter the text file name:')

    # or simply type test.myFile instead of myFile
    import spacy
#     !python -m spacy download en_core_web_sm
    
    import json
    nlp = spacy.load('en_core_web_sm')
    data = open('floop-conv-data.json', 'r')
    jsondata = json.load(data)
    tokens = nlp.pipe(jsondata)
    tokenlist = ''
    for s in tokens:
        tokenlist += s.text
    
    

#     myFile = input('\n'+'Enter a FeedBack:').lower()
    myFile = tokenlist

# to see if the feedback cointains any ? mark
    print('\n'+'******************************************************************')
    print('                     RESULT for this entry                         ')
    print('******************************************************************')

    sentList = nltk.sent_tokenize(myFile)
    sentences_qnt = len(sentList)
    print('\n'+'You entered ', str(sentences_qnt), ' sentences.')

    if '?' in myFile:
        qnt = myFile.count('?')
        print('This entry includes: ' + str(qnt)+' questions!')
        print('\n'+'******************************************************************')
    else:
        print('\n'+'******************************************************************')
        print('There is no question mark in this feedback but wait for more result!')
        print('\n'+'******************************************************************')
        print('Here are more analyses about this entry:'+'\n')

# lists of words that indicates question

    wh_question = ['what', 'when', 'where', 'who',
                   'whom', 'which', 'whose', 'why', 'how']
    yN_question = ["am", "is", "are", "do", "does", "did", "have", "has", "was", "were", "can", "cannot", "could",
                   "couldn't", "dare", "may", "might", "must", "need", "ought", "shall", "should", "shouldn't", "will", "would"]

# initialize

    first_words = []
    type = []
    list_of_question_words = []
    type_sentence = []

# adding first words of all the sentences in one list and adding the last item in one sentence in another list

    for items in sentList:
        first_words.append(items.split(' ')[0])
        type.append(items[-1][-1])
# validatin of words
    for item in type:
        if item == '.':
            type_sentence.append('Sentence')
        elif item == '!':
            type_sentence.append('Exclamatory')
        elif item == '?':
            type_sentence.append('Interrogative')
        else:
            type_sentence.append('Unknown or Numbers')
    for items in first_words:
        if items in wh_question:
            list_of_question_words.append('WH question')
        elif items in yN_question:
            list_of_question_words.append('Y/N question')
# inja -1 mikhad?
    for i in range(len(type)):
        print('Sentence #', str(i+1), 'Type:', type_sentence[i])
        if type_sentence[i] == 'Unknown or Numbers':
            print("This is the type that we did not catch it: ", type[i])
    for i in range(len(list_of_question_words)):
        print('Question #', str(i+1), 'Type:', list_of_question_words[i])

    countQuestionWords = Counter(list_of_question_words)
    print('Summary of question words: ', countQuestionWords)

# cleanup the text and make it as words in a list

    cleanedText = myFile.translate(str.maketrans('', '', string.punctuation))
    tokenizedList = word_tokenize(cleanedText, "english")

# creating a list of stop words in the feedback

    listOfWords = [
        item for item in tokenizedList if item in stopwords.words('english')]
    countstopwords = Counter(listOfWords)

# creating a list of words in the feedback excluded all the stop words

    finalList = [
        item for item in tokenizedList if item not in stopwords.words('english')]

    count = 0
    totalCount = 0
    itemsCount = 0
    for item in tokenizedList:
        itemsCount += 1
        if item in stopwords.words('english'):
            count += 1

# creating a list of emotion words and the words that have emotion according to our pre defined list

    emotionList = []
    wordList = []

# list of words with their emothions

    with open('emotions.txt', 'r') as file:
        for line in file:
            clearLine = line.replace('\n', '').replace(
                ',', '').replace("'", '').replace(' ', '').strip()
            word, emotion = clearLine.split(':')

            if word in finalList:
                emotionList.append(emotion)
                wordList.append(word)
            countEmotions = Counter(emotionList)
            countwords = Counter(finalList)
    totalCount = count+len(set(tokenizedList) -
                           set(wordList)-set(stopwords.words('english')))

    # myFile =Path('/college/Winter2022/Ad450/NLP/test.myFile').read_text().replace('\n','')

# creating a blob text

    blob = TextBlob(myFile)
    wordCount = blob.word_counts

# make all the typos correct

    # correctmyFile = blob.correct()
    # sentences = blob.sentences
    # sen = blob.sentiment

    blob = TextBlob(myFile, analyzer=NaiveBayesAnalyzer())
    sen_sub = blob.sentiment

    def sentimentAnalyse(text):
        score = SentimentIntensityAnalyzer().polarity_scores(text)
        for k,v in score.items():
            print(f"{k}:{v:.2f}")
        neg = score['neg']
        pos = score['pos']
        if neg > pos:
            print("\n"+"In general: Negative sentiment!")
        elif pos > neg:
            print("\n"+"In general: Positive sentiment!")
        else:
            print("\n"+"In general: Neutral vibe!")

    sentimentAnalyse(myFile)
    reg = RegexpTokenizer('(?u)\w+|\$[\d\.]+|\s+')
    # regex_tokenize = RegexpTokenizer.tokenize(myFile)
    # print(regex_tokenize)

    print('\n'+'******************************************************************')
    print('Summary of sentiments:')
    print('\n'+'list of words with emotions: ', wordList)
    print('Summary of emotions count: ', countEmotions)
    print('\n'+'******************************************************************')
    print('                      End of Application                          ')
    print('******************************************************************')

# Drawing the bar chart

    fig, axl = plt.subplots()
    axl.bar(countEmotions.keys(), countEmotions.values())
    fig.autofmt_xdate()
    plt.savefig('graph.png')
    plt.show()

    print(nltk.pos_tag(tokenizedList))
    grammar = r"NP:{<DT>?<JJ>*<NN>}"
    chunk = nltk.RegexpParser(grammar)


main()


##############################################################
# Symbol	Meaning	                Example                  #
#------------------------------------------------------------#
# S	        sentence	            the man walked           #
# NP	    noun phrase	            a dog                    #
# VP  	    verb phrase	            saw a park               #
# PP	    prepositional phrase	with a telescope         #
# Det	    determiner	            the                      #
# N	        noun	                dog                      #
# V	        verb	                walked                   #
# P	        preposition 	        in                       #
##############################################################
# Out:
# [nltk_data] Downloading package nps_chat to
# [nltk_data]     C:\Users\alexb\AppData\Roaming\nltk_data...
# [nltk_data]   Package nps_chat is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\alexb\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package brown to
# [nltk_data]     C:\Users\alexb\AppData\Roaming\nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# [nltk_data] Downloading package movie_reviews to
# [nltk_data]     C:\Users\alexb\AppData\Roaming\nltk_data...
# [nltk_data]   Package movie_reviews is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\alexb\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\alexb\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package tagsets to
# [nltk_data]     C:\Users\alexb\AppData\Roaming\nltk_data...
# [nltk_data]   Package tagsets is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\alexb\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# ******************************************************************
# This application is about Natural Language Processing (NLP).
# The user enters sentence(s) add using NLP and other algorithm the application
# will analyze that entry and gives some feesback.
#
# *****   THIS APPLICATION DOES NOT SUPPORT CONTRACTED FORM    *****
#
# ******************************************************************
#
# ******************************************************************
#                      RESULT for this entry
# ******************************************************************
#
# You entered  121  sentences.
# This entry includes: 91 questions!
#
# ******************************************************************
# Sentence # 1 Type: Interrogative
# Sentence # 2 Type: Exclamatory
# Sentence # 3 Type: Sentence
# Sentence # 4 Type: Sentence
# Sentence # 5 Type: Interrogative
# Sentence # 6 Type: Exclamatory
# Sentence # 7 Type: Sentence
# Sentence # 8 Type: Sentence
# Sentence # 9 Type: Interrogative
# Sentence # 10 Type: Exclamatory
# Sentence # 11 Type: Sentence
# Sentence # 12 Type: Sentence
# Sentence # 13 Type: Interrogative
# Sentence # 14 Type: Sentence
# Sentence # 15 Type: Interrogative
# Sentence # 16 Type: Sentence
# Sentence # 17 Type: Sentence
# Sentence # 18 Type: Sentence
# Sentence # 19 Type: Sentence
# Sentence # 20 Type: Sentence
# Sentence # 21 Type: Sentence
# Sentence # 22 Type: Exclamatory
# Sentence # 23 Type: Interrogative
# Sentence # 24 Type: Interrogative
# Sentence # 25 Type: Sentence
# Sentence # 26 Type: Interrogative
# Sentence # 27 Type: Sentence
# Sentence # 28 Type: Exclamatory
# Sentence # 29 Type: Sentence
# Sentence # 30 Type: Exclamatory
# Sentence # 31 Type: Exclamatory
# Sentence # 32 Type: Exclamatory
# Sentence # 33 Type: Interrogative
# Sentence # 34 Type: Sentence
# Sentence # 35 Type: Sentence
# Sentence # 36 Type: Exclamatory
# Sentence # 37 Type: Sentence
# Sentence # 38 Type: Sentence
# Sentence # 39 Type: Sentence
# Sentence # 40 Type: Sentence
# Sentence # 41 Type: Sentence
# Sentence # 42 Type: Sentence
# Sentence # 43 Type: Exclamatory
# Sentence # 44 Type: Sentence
# Sentence # 45 Type: Interrogative
# Sentence # 46 Type: Sentence
# Sentence # 47 Type: Interrogative
# Sentence # 48 Type: Sentence
# Sentence # 49 Type: Sentence
# Sentence # 50 Type: Sentence
# Sentence # 51 Type: Sentence
# Sentence # 52 Type: Sentence
# Sentence # 53 Type: Sentence
# Sentence # 54 Type: Sentence
# Sentence # 55 Type: Exclamatory
# Sentence # 56 Type: Sentence
# Sentence # 57 Type: Sentence
# Sentence # 58 Type: Sentence
# Sentence # 59 Type: Sentence
# Sentence # 60 Type: Sentence
# Sentence # 61 Type: Sentence
# Sentence # 62 Type: Interrogative
# Sentence # 63 Type: Exclamatory
# Sentence # 64 Type: Exclamatory
# Sentence # 65 Type: Sentence
# Sentence # 66 Type: Exclamatory
# Sentence # 67 Type: Sentence
# Sentence # 68 Type: Sentence
# Sentence # 69 Type: Exclamatory
# Sentence # 70 Type: Sentence
# Sentence # 71 Type: Exclamatory
# Sentence # 72 Type: Sentence
# Sentence # 73 Type: Sentence
# Sentence # 74 Type: Interrogative
# Sentence # 75 Type: Interrogative
# Sentence # 76 Type: Exclamatory
# Sentence # 77 Type: Interrogative
# Sentence # 78 Type: Sentence
# Sentence # 79 Type: Sentence
# Sentence # 80 Type: Interrogative
# Sentence # 81 Type: Interrogative
# Sentence # 82 Type: Interrogative
# Sentence # 83 Type: Exclamatory
# Sentence # 84 Type: Exclamatory
# Sentence # 85 Type: Exclamatory
# Sentence # 86 Type: Exclamatory
# Sentence # 87 Type: Sentence
# Sentence # 88 Type: Interrogative
# Sentence # 89 Type: Interrogative
# Sentence # 90 Type: Interrogative
# Sentence # 91 Type: Exclamatory
# Sentence # 92 Type: Exclamatory
# Sentence # 93 Type: Exclamatory
# Sentence # 94 Type: Sentence
# Sentence # 95 Type: Sentence
# Sentence # 96 Type: Sentence
# Sentence # 97 Type: Sentence
# Sentence # 98 Type: Exclamatory
# Sentence # 99 Type: Sentence
# Sentence # 100 Type: Sentence
# Sentence # 101 Type: Sentence
# Sentence # 102 Type: Exclamatory
# Sentence # 103 Type: Exclamatory
# Sentence # 104 Type: Sentence
# Sentence # 105 Type: Interrogative
# Sentence # 106 Type: Exclamatory
# Sentence # 107 Type: Sentence
# Sentence # 108 Type: Sentence
# Sentence # 109 Type: Sentence
# Sentence # 110 Type: Sentence
# Sentence # 111 Type: Sentence
# Sentence # 112 Type: Sentence
# Sentence # 113 Type: Sentence
# Sentence # 114 Type: Sentence
# Sentence # 115 Type: Sentence
# Sentence # 116 Type: Interrogative
# Sentence # 117 Type: Exclamatory
# Sentence # 118 Type: Sentence
# Sentence # 119 Type: Sentence
# Sentence # 120 Type: Exclamatory
# Sentence # 121 Type: Exclamatory
# Question # 1 Type: Y/N question
# Summary of question words:  Counter({'Y/N question': 1})
# neg:0.03
# neu:0.85
# pos:0.12
# compound:1.00
#
# In general: Positive sentiment!
#
# ******************************************************************
# Summary of sentiments:
#
# list of words with emotions:  ['free', 'low', 'organized', 'sad', 'strong', 'yellow', 'great', 'low', 'good', 'nice', 'bad']
# Summary of emotions count:  Counter({'sad': 4, 'happy': 3, 'free': 1, 'adequate': 1, 'independent': 1, 'fearful': 1})
#
# ******************************************************************
#                       End of Application
# ******************************************************************
# [('DogChange', 'NN'), ('this', 'DT'), ('colorstaffffvhere', 'JJ'), ('yo', 'NN'), ('feedbackgrain', 'NN'), ('siloGood', 'NN'), ('jobfddtest', 'NN'), ('c', 'VBD'), ('1Test1', 'CD'), ('feedback', 'NN'), ('teacherLook', 'NN'), ('at', 'IN'), ('this', 'DT'), ('drawing34', 'NN'), ('bottomFF', 'NN'), ('Convo1wanna', 'NNP'), ('see', 'VBP'), ('the', 'DT'), ('longest', 'JJS'), ('comment', 'NN'), ('in', 'IN'), ('the', 'DT'), ('world', 'NN'), ('here', 'RB'), ('it', 'PRP'), ('is', 'VBZ'), ('this', 'DT'), ('is', 'VBZ'), ('a', 'DT'), ('loooooooonnnng', 'JJ'), ('comment', 'NN'), ('buddy', 'VBD'), ('A', 'NNP'), ('loooooooong', 'JJ'), ('one', 'CD'), ('wan', 'NN'), ('na', 'CC'), ('see', 'VB'), ('the', 'DT'), ('longest', 'JJS'), ('comment', 'NN'), ('in', 'IN'), ('the', 'DT'), ('world', 'NN'), ('here', 'RB'), ('it', 'PRP'), ('is', 'VBZ'), ('this', 'DT'), ('is', 'VBZ'), ('a', 'DT'), ('loooooooonnnng', 'JJ'), ('comment', 'NN'), ('buddy', 'VBD'), ('A', 'NNP'), ('loooooooong', 'JJ'), ('one', 'CD'), ('wan', 'NN'), ('na', 'CC'), ('see', 'VB'), ('the', 'DT'), ('longest', 'JJS'), ('comment', 'NN'), ('in', 'IN'), ('the', 'DT'), ('world', 'NN'), ('here', 'RB'), ('it', 'PRP'), ('is', 'VBZ'), ('this', 'DT'), ('is', 'VBZ'), ('a', 'DT'), ('loooooooonnnng', 'JJ'), ('comment', 'NN'), ('buddy', 'VBD'), ('A', 'NNP'), ('loooooooong', 'JJ'), ('oneniceGood', 'NN'), ('work', 'NN'), ('Peter', 'NNP'), ('Studentadding', 'NNP'), ('another', 'DT'), ('commentBottom', 'NN'), ('of', 'IN'), ('image', 'NN'), ('1Audio', 'CD'), ('Comment', 'NNP'), ('s', 'NN'), ('sdfasdf', 'NN'), ('sdf', 'NN'), ('sdfs', 'NN'), ('daf', 'NN'), ('sdf', 'NN'), ('sfdasdf', 'NN'), ('asf', 'IN'), ('dasf', 'NN'), ('ad', 'NN'), ('sdaff', 'NN'), ('sda', 'NN'), ('dsaf', 'NN'), ('sfda', 'NN'), ('asfdf', 'JJ'), ('dsa', 'NN'), ('dsa', 'NN'), ('sddsfasdf', 'VBD'), ('a', 'DT'), ('sdfasf', 'JJ'), ('dmoonbtext', 'NN'), ('commentPretty', 'NN'), ('readable', 'JJ'), ('to', 'TO'), ('measdasfFdont', 'VB'), ('saveWhat', 'WP'), ('a', 'DT'), ('valleymid', 'NN'), ('mid', 'NN'), ('xPeter', 'NNP'), ('testAfirst', 'RB'), ('line', 'NN'), ('above', 'IN'), ('34', 'CD'), ('circle', 'NN'), ('xUnarchivingicetest', 'NNP'), ('x2', 'NN'), ('and', 'CC'), ('2xnice', 'CD'), ('lakeHot', 'JJ'), ('DawgHONKttlVery', 'NNP'), ('cloudy', 'NN'), ('FirstNameI', 'NNP'), ('love', 'NN'), ('travelingbaconnnHello', 'NN'), ('Jamesff1Great', 'NNP'), ('Job', 'NNP'), ('FirstNamegggCircle2test', 'NNP'), ('submithockey', 'NN'), ('playergreat', 'NN'), ('firstnameHow', 'WRB'), ('do', 'VBP'), ('you', 'PRP'), ('know', 'VB'), ('my', 'PRP$'), ('password', 'NN'), ('vcvchello', 'NN'), ('friendsneedle', 'JJ'), ('topgbbbbBeautifulbottom', 'NN'), ('right', 'NN'), ('Xharry', 'NNP'), ('potter', 'RB'), ('comment', 'VBD'), ('2ff2freeformSome', 'CD'), ('outlines', 'NNS'), ('for', 'IN'), ('youThis', 'NN'), ('is', 'VBZ'), ('good', 'JJ'), ('work', 'NN'), ('Where', 'WRB'), ('did', 'VBD'), ('you', 'PRP'), ('find', 'VB'), ('these', 'DT'), ('statistics', 'NNS'), ('above', 'IN'), ('spot', 'NN'), ('xNow', 'NNP'), ('Petertop', 'NNP'), ('leftNow', 'NN'), ('FirstNamedsfgjuhkhklkloveHarry', 'NNP'), ('Pottertop', 'NNP'), ('right', 'NN'), ('x', 'NNP'), ('midasfasdfGood', 'NN'), ('workyohoVery', 'NN'), ('cloudy', 'NN'), ('Petersddv1center', 'NNP'), ('of', 'IN'), ('chocolate', 'NN'), ('popcornHow', 'NN'), ('did', 'VBD'), ('you', 'PRP'), ('create', 'VB'), ('that', 'IN'), ('colorLotsa', 'JJ'), ('fansTest2Great', 'NN'), ('Job', 'NNP'), ('FirstNamefgfLooks', 'NNP'), ('like', 'IN'), ('a', 'DT'), ('good', 'JJ'), ('hill', 'NN'), ('to', 'TO'), ('scaleBottom', 'VB'), ('Rightyummy', 'NNP'), ('dumplingsblahtop', 'VB'), ('rightparadisetestd', 'NN'), ('PeterLike', 'IN'), ('the', 'DT'), ('buttontryrtyGJPerfectwet', 'NN'), ('rocksHow', 'VBZ'), ('about', 'RB'), ('now', 'RB'), ('FirstNamebottomtest', 'NNP'), ('com', 'NN'), ('1', 'CD'), ('gmailSnowy', 'NN'), ('dayNice', 'NN'), ('commenttest', 'NN'), ('audio', 'NN'), ('commentHmmGood', 'NN'), ('use', 'NN'), ('of', 'IN'), ('resource', 'NN'), ('groupsasdlfkjasdfl ...
